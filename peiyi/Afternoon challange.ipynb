# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score, roc_curve, auc, roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
data_path = 'D:/University documents/Year 4/Data Science Challange/transactions_training_sept_oct_2023(1).csv'
train = pd.read_csv(
    data_path,
    sep=";",               # séparateur de colonnes
    decimal=",",           # virgule comme séparateur décimal
    na_values="NA",        # valeur manquante
    parse_dates=["DATETIME_GMT"]  # convertir la colonne date
)

test_data_path = 'D:/University documents/Year 4/Data Science Challange/transactions_unclassified_2023(1).csv'
test = pd.read_csv(
    test_data_path,
    sep=";",               # séparateur de colonnes
    decimal=",",           # virgule comme séparateur décimal
    na_values="NA",        # valeur manquante
    parse_dates=["DATETIME_GMT"]  # convertir la colonne date
)

# %%
print(train["FLAG_FRAUD"].value_counts())
print(train["FLAG_FRAUD"].value_counts(normalize=True) * 100)
# Out:
# FLAG_FRAUD
# 0    79908
# 1       92
# Name: count, dtype: int64
# FLAG_FRAUD
# 0    99.885
# 1     0.115
# Name: proportion, dtype: float64

# %%
train.isna().sum()
# Out:
# ID_TRX                          0
# ID_CARD                         0
# DATETIME_GMT                    0
# AMOUNT                          0
# Anomaly_amount_1                0
# Anomaly_amount_2                0
# Anomaly_amount_3                0
# Anomaly_amount_4                0
# Anomaly_amount_5                0
# Anomaly_amount_6                0
# Anomaly_amount_7                0
# Anomaly_amount_8                0
# FLAG_BEHAVIOUR_Anomaly_1        0
# FLAG_BEHAVIOUR_Anomaly_2        0
# FLAG_BEHAVIOUR_Anomaly_3        0
# FLAG_BEHAVIOUR_Anomaly_4        0
# FLAG_BEHAVIOUR_Anomaly_5        0
# FLAG_BEHAVIOUR_Anomaly_6        0
# FLAG_BEHAVIOUR_Anomaly7         0
# FLAG_BEHAVIOUR_Anomaly_8        0
# Anomaly_amount_9            19816
# Population_Anomaly_1            0
# Population_Anomaly_2            0
# Population_Anomaly_3            0
# Population_Anomaly_4            0
# Population_Anomaly_5            0
# Population_Anomaly_6            0
# Population_Anomaly_7            0
# Population_Anomaly_8            0
# FLAG_FRAUD                      0
# dtype: int64

# %%
test.isna().sum()
# Out:
# ID_TRX                         0
# ID_CARD                        0
# DATETIME_GMT                   0
# AMOUNT                         0
# Anomaly_amount_1               0
# Anomaly_amount_2               0
# Anomaly_amount_3               0
# Anomaly_amount_4               0
# Anomaly_amount_5               0
# Anomaly_amount_6               0
# Anomaly_amount_7               0
# Anomaly_amount_8               0
# FLAG_BEHAVIOUR_Anomaly_1       0
# FLAG_BEHAVIOUR_Anomaly_2       0
# FLAG_BEHAVIOUR_Anomaly_3       0
# FLAG_BEHAVIOUR_Anomaly_4       0
# FLAG_BEHAVIOUR_Anomaly_5       0
# FLAG_BEHAVIOUR_Anomaly_6       0
# FLAG_BEHAVIOUR_Anomaly7        0
# FLAG_BEHAVIOUR_Anomaly_8       0
# Anomaly_amount_9            2839
# Population_Anomaly_1           0
# Population_Anomaly_2           0
# Population_Anomaly_3           0
# Population_Anomaly_4           0
# Population_Anomaly_5           0
# Population_Anomaly_6           0
# Population_Anomaly_7           0
# Population_Anomaly_8           0
# dtype: int64

# %%
# On trie par carte + date pour bien aligner les historiques
train = train.sort_values(by=["ID_CARD", "DATETIME_GMT"])

# Calcul du temps écoulé depuis la dernière transaction (en secondes)
train["time_since_last_txn"] = train.groupby("ID_CARD")["DATETIME_GMT"].diff().dt.total_seconds()

# Calcul de la différence d'amount depuis la dernière transaction
train["amount_diff_since_last_txn"] = train.groupby("ID_CARD")["AMOUNT"].diff()

train["hour"] = train["DATETIME_GMT"].dt.hour
train["dayofweek"] = train["DATETIME_GMT"].dt.dayofweek
train["is_night"] = train["hour"].apply(lambda h: 1 if h < 6 or h >= 22 else 0)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import f1_score, classification_report

# %%
# 1. Séparation X / y
X = train.drop(columns=["ID_TRX", "ID_CARD", "FLAG_FRAUD","DATETIME_GMT"])
y = train["FLAG_FRAUD"].astype(int)  # au cas où c’est encore un str
weight = (y == 0).sum() / (y == 1).sum()

# Tri du dataset par date croissante
sorted_df = train.sort_values("DATETIME_GMT").reset_index(drop=True)

# Taille du split (20% en test)
split_idx = int(len(sorted_df) * 0.8)

# Séparation manuelle
train_df = sorted_df.iloc[:split_idx]
test_df  = sorted_df.iloc[split_idx:]

# Séparation X / y
X_train = train_df.drop(columns=["ID_TRX", "ID_CARD", "FLAG_FRAUD","DATETIME_GMT"])
y_train = train_df["FLAG_FRAUD"].astype(int)

X_test = test_df.drop(columns=["ID_TRX", "ID_CARD", "FLAG_FRAUD","DATETIME_GMT"])
y_test = test_df["FLAG_FRAUD"].astype(int)

# %%
# 3. Initialise the XGBoost model
model = XGBClassifier(
    objective="binary:logistic",
    use_label_encoder=False,
    eval_metric="logloss",  # évite warning
    n_estimators=1000,
    scale_pos_weight=weight,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

# %%
from sklearn.model_selection import RandomizedSearchCV

# 4. Hyperparameter tuning with RandomizedSearchCV
param_dist = {
    'max_depth': [5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.05, 0.1],
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.6, 0.8, 1.0]
}

search = RandomizedSearchCV(
    model, param_dist,
    n_iter=50, scoring='f1', cv=5, n_jobs=-1, random_state=42
)

search.fit(X_train, y_train)
print("Best params:", search.best_params_)
print("Best CV F1:", search.best_score_)
# Out:
# c:\Users\brian\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [15:04:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best params: {'subsample': 0.8, 'max_depth': 5, 'learning_rate': 0.05, 'colsample_bytree': 0.6}
# Best CV F1: 0.6647619047619048

# %%
best_model = XGBClassifier(
    objective="binary:logistic",
    use_label_encoder=False,
    eval_metric="aucpr",  # for imbalanced datasets
    n_estimators=1000,
    scale_pos_weight=weight,
    random_state=42,
    **search.best_params_,   # automatically apply best found hyperparameters
    early_stopping_rounds=50  # stop early if no improvement
)

best_model.fit(X_train, y_train, eval_set=[(X_test, y_test)])

# 5. Prédictions (avec seuil par défaut = 0.5)
y_pred = best_model.predict(X_test)
# Out:
# [0]	validation_0-aucpr:0.08119
# [1]	validation_0-aucpr:0.22355
# [2]	validation_0-aucpr:0.26481
# [3]	validation_0-aucpr:0.42998
# [4]	validation_0-aucpr:0.43051
# [5]	validation_0-aucpr:0.42869
# [6]	validation_0-aucpr:0.43085
# [7]	validation_0-aucpr:0.46262
# [8]	validation_0-aucpr:0.46440
# [9]	validation_0-aucpr:0.46361
# [10]	validation_0-aucpr:0.45376
# [11]	validation_0-aucpr:0.45417
# [12]	validation_0-aucpr:0.45373
# [13]	validation_0-aucpr:0.45374
# [14]	validation_0-aucpr:0.45339
# [15]	validation_0-aucpr:0.45503
# [16]	validation_0-aucpr:0.47769
# [17]	validation_0-aucpr:0.47770
# [18]	validation_0-aucpr:0.47802
# [19]	validation_0-aucpr:0.48874
# [20]	validation_0-aucpr:0.49008
# [21]	validation_0-aucpr:0.48922
# [22]	validation_0-aucpr:0.50895
# [23]	validation_0-aucpr:0.50956
# [24]	validation_0-aucpr:0.51179
# [25]	validation_0-aucpr:0.51212
# [26]	validation_0-aucpr:0.51240
# [27]	validation_0-aucpr:0.51171
# [28]	validation_0-aucpr:0.51098
# [29]	validation_0-aucpr:0.74277
# [30]	validation_0-aucpr:0.74276
# [31]	validation_0-aucpr:0.74245
# [32]	validation_0-aucpr:0.74231
# [33]	validation_0-aucpr:0.74156
# c:\Users\brian\anaconda3\lib\site-packages\xgboost\core.py:158: UserWarning: [15:04:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [34]	validation_0-aucpr:0.74182
# [35]	validation_0-aucpr:0.74317
# [36]	validation_0-aucpr:0.74320
# [37]	validation_0-aucpr:0.74262
# [38]	validation_0-aucpr:0.74257
# [39]	validation_0-aucpr:0.74236
# [40]	validation_0-aucpr:0.74380
# [41]	validation_0-aucpr:0.74444
# [42]	validation_0-aucpr:0.74020
# [43]	validation_0-aucpr:0.73974
# [44]	validation_0-aucpr:0.73947
# [45]	validation_0-aucpr:0.74340
# [46]	validation_0-aucpr:0.74443
# [47]	validation_0-aucpr:0.74423
# [48]	validation_0-aucpr:0.74462
# [49]	validation_0-aucpr:0.59109
# [50]	validation_0-aucpr:0.59206
# [51]	validation_0-aucpr:0.64673
# [52]	validation_0-aucpr:0.64686
# [53]	validation_0-aucpr:0.64719
# [54]	validation_0-aucpr:0.64856
# [55]	validation_0-aucpr:0.64853
# [56]	validation_0-aucpr:0.64800
# [57]	validation_0-aucpr:0.68617
# [58]	validation_0-aucpr:0.71769
# [59]	validation_0-aucpr:0.76757
# [60]	validation_0-aucpr:0.77264
# [61]	validation_0-aucpr:0.81733
# [62]	validation_0-aucpr:0.81773
# [63]	validation_0-aucpr:0.81800
# [64]	validation_0-aucpr:0.80172
# [65]	validation_0-aucpr:0.80149
# [66]	validation_0-aucpr:0.80223
# [67]	validation_0-aucpr:0.80211
# [68]	validation_0-aucpr:0.80265
# [69]	validation_0-aucpr:0.80547
# [70]	validation_0-aucpr:0.81845
# [71]	validation_0-aucpr:0.81910
# [72]	validation_0-aucpr:0.82133
# [73]	validation_0-aucpr:0.82300
# [74]	validation_0-aucpr:0.82301
# [75]	validation_0-aucpr:0.82253
# [76]	validation_0-aucpr:0.82430
# [77]	validation_0-aucpr:0.82749
# [78]	validation_0-aucpr:0.82681
# [79]	validation_0-aucpr:0.82250
# [80]	validation_0-aucpr:0.83029
# [81]	validation_0-aucpr:0.83467
# [82]	validation_0-aucpr:0.83480
# [83]	validation_0-aucpr:0.83566
# [84]	validation_0-aucpr:0.83559
# [85]	validation_0-aucpr:0.83558
# [86]	validation_0-aucpr:0.82808
# [87]	validation_0-aucpr:0.82858
# [88]	validation_0-aucpr:0.82927
# [89]	validation_0-aucpr:0.82795
# [90]	validation_0-aucpr:0.82666
# [91]	validation_0-aucpr:0.82655
# [92]	validation_0-aucpr:0.82892
# [93]	validation_0-aucpr:0.82865
# [94]	validation_0-aucpr:0.83087
# [95]	validation_0-aucpr:0.82880
# [96]	validation_0-aucpr:0.83124
# [97]	validation_0-aucpr:0.83167
# [98]	validation_0-aucpr:0.83036
# [99]	validation_0-aucpr:0.83059
# [100]	validation_0-aucpr:0.83013
# [101]	validation_0-aucpr:0.82895
# [102]	validation_0-aucpr:0.82873
# [103]	validation_0-aucpr:0.82930
# [104]	validation_0-aucpr:0.82906
# [105]	validation_0-aucpr:0.82926
# [106]	validation_0-aucpr:0.82974
# [107]	validation_0-aucpr:0.82797
# [108]	validation_0-aucpr:0.83024
# [109]	validation_0-aucpr:0.83009
# [110]	validation_0-aucpr:0.83044
# [111]	validation_0-aucpr:0.83197
# [112]	validation_0-aucpr:0.83096
# [113]	validation_0-aucpr:0.83107
# [114]	validation_0-aucpr:0.83110
# [115]	validation_0-aucpr:0.83321
# [116]	validation_0-aucpr:0.83206
# [117]	validation_0-aucpr:0.82989
# [118]	validation_0-aucpr:0.83163
# [119]	validation_0-aucpr:0.83131
# [120]	validation_0-aucpr:0.83162
# [121]	validation_0-aucpr:0.83156
# [122]	validation_0-aucpr:0.83327
# [123]	validation_0-aucpr:0.83345
# [124]	validation_0-aucpr:0.83643
# [125]	validation_0-aucpr:0.83662
# [126]	validation_0-aucpr:0.83691
# [127]	validation_0-aucpr:0.83711
# [128]	validation_0-aucpr:0.83655
# [129]	validation_0-aucpr:0.83724
# [130]	validation_0-aucpr:0.83483
# [131]	validation_0-aucpr:0.83638
# [132]	validation_0-aucpr:0.83715
# [133]	validation_0-aucpr:0.83829
# [134]	validation_0-aucpr:0.83675
# [135]	validation_0-aucpr:0.83796
# [136]	validation_0-aucpr:0.83696
# [137]	validation_0-aucpr:0.83747
# [138]	validation_0-aucpr:0.83754
# [139]	validation_0-aucpr:0.83737
# [140]	validation_0-aucpr:0.83624
# [141]	validation_0-aucpr:0.83606
# [142]	validation_0-aucpr:0.83634
# [143]	validation_0-aucpr:0.83607
# [144]	validation_0-aucpr:0.83536
# [145]	validation_0-aucpr:0.83497
# [146]	validation_0-aucpr:0.83433
# [147]	validation_0-aucpr:0.83378
# [148]	validation_0-aucpr:0.83571
# [149]	validation_0-aucpr:0.83545
# [150]	validation_0-aucpr:0.83558
# [151]	validation_0-aucpr:0.83515
# [152]	validation_0-aucpr:0.83567
# [153]	validation_0-aucpr:0.83550
# [154]	validation_0-aucpr:0.83549
# [155]	validation_0-aucpr:0.83529
# [156]	validation_0-aucpr:0.83512
# [157]	validation_0-aucpr:0.83562
# [158]	validation_0-aucpr:0.83558
# [159]	validation_0-aucpr:0.83654
# [160]	validation_0-aucpr:0.83832
# [161]	validation_0-aucpr:0.83862
# [162]	validation_0-aucpr:0.84007
# [163]	validation_0-aucpr:0.84045
# [164]	validation_0-aucpr:0.84014
# [165]	validation_0-aucpr:0.84009
# [166]	validation_0-aucpr:0.84052
# [167]	validation_0-aucpr:0.84062
# [168]	validation_0-aucpr:0.84059
# [169]	validation_0-aucpr:0.84110
# [170]	validation_0-aucpr:0.84135
# [171]	validation_0-aucpr:0.84138
# [172]	validation_0-aucpr:0.84134
# [173]	validation_0-aucpr:0.84118
# [174]	validation_0-aucpr:0.84084
# [175]	validation_0-aucpr:0.84078
# [176]	validation_0-aucpr:0.84114
# [177]	validation_0-aucpr:0.84133
# [178]	validation_0-aucpr:0.84190
# [179]	validation_0-aucpr:0.84152
# [180]	validation_0-aucpr:0.84173
# [181]	validation_0-aucpr:0.84145
# [182]	validation_0-aucpr:0.84223
# [183]	validation_0-aucpr:0.84199
# [184]	validation_0-aucpr:0.84179
# [185]	validation_0-aucpr:0.84172
# [186]	validation_0-aucpr:0.84185
# [187]	validation_0-aucpr:0.84185
# [188]	validation_0-aucpr:0.84295
# [189]	validation_0-aucpr:0.84341
# [190]	validation_0-aucpr:0.84397
# [191]	validation_0-aucpr:0.84379
# [192]	validation_0-aucpr:0.84375
# [193]	validation_0-aucpr:0.84389
# [194]	validation_0-aucpr:0.84476
# [195]	validation_0-aucpr:0.84460
# [196]	validation_0-aucpr:0.84468
# [197]	validation_0-aucpr:0.84486
# [198]	validation_0-aucpr:0.84464
# [199]	validation_0-aucpr:0.84542
# [200]	validation_0-aucpr:0.84516
# [201]	validation_0-aucpr:0.84634
# [202]	validation_0-aucpr:0.84646
# [203]	validation_0-aucpr:0.84702
# [204]	validation_0-aucpr:0.84709
# [205]	validation_0-aucpr:0.84724
# [206]	validation_0-aucpr:0.84725
# [207]	validation_0-aucpr:0.84721
# [208]	validation_0-aucpr:0.84816
# [209]	validation_0-aucpr:0.84826
# [210]	validation_0-aucpr:0.84799
# [211]	validation_0-aucpr:0.84868
# [212]	validation_0-aucpr:0.84930
# [213]	validation_0-aucpr:0.84926
# [214]	validation_0-aucpr:0.84997
# [215]	validation_0-aucpr:0.84992
# [216]	validation_0-aucpr:0.85083
# [217]	validation_0-aucpr:0.85088
# [218]	validation_0-aucpr:0.85080
# [219]	validation_0-aucpr:0.85084
# [220]	validation_0-aucpr:0.85114
# [221]	validation_0-aucpr:0.85151
# [222]	validation_0-aucpr:0.85173
# [223]	validation_0-aucpr:0.85203
# [224]	validation_0-aucpr:0.85238
# [225]	validation_0-aucpr:0.85240
# [226]	validation_0-aucpr:0.85197
# [227]	validation_0-aucpr:0.85172
# [228]	validation_0-aucpr:0.85172
# [229]	validation_0-aucpr:0.85175
# [230]	validation_0-aucpr:0.85183
# [231]	validation_0-aucpr:0.85221
# [232]	validation_0-aucpr:0.85234
# [233]	validation_0-aucpr:0.85207
# [234]	validation_0-aucpr:0.85219
# [235]	validation_0-aucpr:0.85230
# [236]	validation_0-aucpr:0.85244
# [237]	validation_0-aucpr:0.85262
# [238]	validation_0-aucpr:0.85283
# [239]	validation_0-aucpr:0.85307
# [240]	validation_0-aucpr:0.85317
# [241]	validation_0-aucpr:0.85317
# [242]	validation_0-aucpr:0.85325
# [243]	validation_0-aucpr:0.85402
# [244]	validation_0-aucpr:0.85503
# [245]	validation_0-aucpr:0.85608
# [246]	validation_0-aucpr:0.85618
# [247]	validation_0-aucpr:0.85575
# [248]	validation_0-aucpr:0.85596
# [249]	validation_0-aucpr:0.85563
# [250]	validation_0-aucpr:0.85550
# [251]	validation_0-aucpr:0.85466
# [252]	validation_0-aucpr:0.85483
# [253]	validation_0-aucpr:0.85531
# [254]	validation_0-aucpr:0.85543
# [255]	validation_0-aucpr:0.85568
# [256]	validation_0-aucpr:0.85743
# [257]	validation_0-aucpr:0.85801
# [258]	validation_0-aucpr:0.85658
# [259]	validation_0-aucpr:0.85706
# [260]	validation_0-aucpr:0.85841
# [261]	validation_0-aucpr:0.85872
# [262]	validation_0-aucpr:0.85886
# [263]	validation_0-aucpr:0.85900
# [264]	validation_0-aucpr:0.85787
# [265]	validation_0-aucpr:0.85817
# [266]	validation_0-aucpr:0.85806
# [267]	validation_0-aucpr:0.85830
# [268]	validation_0-aucpr:0.85812
# [269]	validation_0-aucpr:0.85831
# [270]	validation_0-aucpr:0.85837
# [271]	validation_0-aucpr:0.85773
# [272]	validation_0-aucpr:0.85844
# [273]	validation_0-aucpr:0.85787
# [274]	validation_0-aucpr:0.85779
# [275]	validation_0-aucpr:0.85739
# [276]	validation_0-aucpr:0.85750
# [277]	validation_0-aucpr:0.85726
# [278]	validation_0-aucpr:0.85701
# [279]	validation_0-aucpr:0.85780
# [280]	validation_0-aucpr:0.85725
# [281]	validation_0-aucpr:0.85810
# [282]	validation_0-aucpr:0.85829
# [283]	validation_0-aucpr:0.85849
# [284]	validation_0-aucpr:0.85945
# [285]	validation_0-aucpr:0.85873
# [286]	validation_0-aucpr:0.85926
# [287]	validation_0-aucpr:0.86008
# [288]	validation_0-aucpr:0.85948
# [289]	validation_0-aucpr:0.85989
# [290]	validation_0-aucpr:0.85983
# [291]	validation_0-aucpr:0.85998
# [292]	validation_0-aucpr:0.86004
# [293]	validation_0-aucpr:0.86031
# [294]	validation_0-aucpr:0.86016
# [295]	validation_0-aucpr:0.86089
# [296]	validation_0-aucpr:0.86090
# [297]	validation_0-aucpr:0.86088
# [298]	validation_0-aucpr:0.86081
# [299]	validation_0-aucpr:0.85988
# [300]	validation_0-aucpr:0.86038
# [301]	validation_0-aucpr:0.86037
# [302]	validation_0-aucpr:0.86047
# [303]	validation_0-aucpr:0.86168
# [304]	validation_0-aucpr:0.86138
# [305]	validation_0-aucpr:0.86182
# [306]	validation_0-aucpr:0.86155
# [307]	validation_0-aucpr:0.86145
# [308]	validation_0-aucpr:0.86049
# [309]	validation_0-aucpr:0.86130
# [310]	validation_0-aucpr:0.86213
# [311]	validation_0-aucpr:0.86233
# [312]	validation_0-aucpr:0.86225
# [313]	validation_0-aucpr:0.86214
# [314]	validation_0-aucpr:0.86227
# [315]	validation_0-aucpr:0.86128
# [316]	validation_0-aucpr:0.86142
# [317]	validation_0-aucpr:0.86131
# [318]	validation_0-aucpr:0.86154
# [319]	validation_0-aucpr:0.86137
# [320]	validation_0-aucpr:0.86165
# [321]	validation_0-aucpr:0.86073
# [322]	validation_0-aucpr:0.86134
# [323]	validation_0-aucpr:0.86062
# [324]	validation_0-aucpr:0.86079
# [325]	validation_0-aucpr:0.86092
# [326]	validation_0-aucpr:0.86113
# [327]	validation_0-aucpr:0.86196
# [328]	validation_0-aucpr:0.86091
# [329]	validation_0-aucpr:0.86180
# [330]	validation_0-aucpr:0.86094
# [331]	validation_0-aucpr:0.86196
# [332]	validation_0-aucpr:0.86196
# [333]	validation_0-aucpr:0.86207
# [334]	validation_0-aucpr:0.86192
# [335]	validation_0-aucpr:0.86200
# [336]	validation_0-aucpr:0.86197
# [337]	validation_0-aucpr:0.86178
# [338]	validation_0-aucpr:0.86194
# [339]	validation_0-aucpr:0.86194
# [340]	validation_0-aucpr:0.86187
# [341]	validation_0-aucpr:0.86194
# [342]	validation_0-aucpr:0.86185
# [343]	validation_0-aucpr:0.86197
# [344]	validation_0-aucpr:0.86199
# [345]	validation_0-aucpr:0.86210
# [346]	validation_0-aucpr:0.86222
# [347]	validation_0-aucpr:0.86213
# [348]	validation_0-aucpr:0.86243
# [349]	validation_0-aucpr:0.86265
# [350]	validation_0-aucpr:0.86276
# [351]	validation_0-aucpr:0.86271
# [352]	validation_0-aucpr:0.86271
# [353]	validation_0-aucpr:0.86272
# [354]	validation_0-aucpr:0.86257
# [355]	validation_0-aucpr:0.86251
# [356]	validation_0-aucpr:0.86237
# [357]	validation_0-aucpr:0.86252
# [358]	validation_0-aucpr:0.86243
# [359]	validation_0-aucpr:0.86232
# [360]	validation_0-aucpr:0.86259
# [361]	validation_0-aucpr:0.86254
# [362]	validation_0-aucpr:0.86283
# [363]	validation_0-aucpr:0.86271
# [364]	validation_0-aucpr:0.86291
# [365]	validation_0-aucpr:0.86284
# [366]	validation_0-aucpr:0.86297
# [367]	validation_0-aucpr:0.86300
# [368]	validation_0-aucpr:0.86296
# [369]	validation_0-aucpr:0.86391
# [370]	validation_0-aucpr:0.86405
# [371]	validation_0-aucpr:0.86412
# [372]	validation_0-aucpr:0.86424
# [373]	validation_0-aucpr:0.86424
# [374]	validation_0-aucpr:0.86413
# [375]	validation_0-aucpr:0.86419
# [376]	validation_0-aucpr:0.86455
# [377]	validation_0-aucpr:0.86480
# [378]	validation_0-aucpr:0.86529
# [379]	validation_0-aucpr:0.86561
# [380]	validation_0-aucpr:0.86686
# [381]	validation_0-aucpr:0.86698
# [382]	validation_0-aucpr:0.86696
# [383]	validation_0-aucpr:0.86688
# [384]	validation_0-aucpr:0.86693
# [385]	validation_0-aucpr:0.86509
# [386]	validation_0-aucpr:0.86565
# [387]	validation_0-aucpr:0.86585
# [388]	validation_0-aucpr:0.86550
# [389]	validation_0-aucpr:0.86595
# [390]	validation_0-aucpr:0.86599
# [391]	validation_0-aucpr:0.86599
# [392]	validation_0-aucpr:0.86612
# [393]	validation_0-aucpr:0.86615
# [394]	validation_0-aucpr:0.86724
# [395]	validation_0-aucpr:0.86708
# [396]	validation_0-aucpr:0.86705
# [397]	validation_0-aucpr:0.86677
# [398]	validation_0-aucpr:0.86658
# [399]	validation_0-aucpr:0.86554
# [400]	validation_0-aucpr:0.86616
# [401]	validation_0-aucpr:0.86635
# [402]	validation_0-aucpr:0.86564
# [403]	validation_0-aucpr:0.86565
# [404]	validation_0-aucpr:0.86622
# [405]	validation_0-aucpr:0.86628
# [406]	validation_0-aucpr:0.86521
# [407]	validation_0-aucpr:0.86632
# [408]	validation_0-aucpr:0.86631
# [409]	validation_0-aucpr:0.86603
# [410]	validation_0-aucpr:0.86605
# [411]	validation_0-aucpr:0.86568
# [412]	validation_0-aucpr:0.86719
# [413]	validation_0-aucpr:0.86725
# [414]	validation_0-aucpr:0.86682
# [415]	validation_0-aucpr:0.86695
# [416]	validation_0-aucpr:0.86661
# [417]	validation_0-aucpr:0.86632
# [418]	validation_0-aucpr:0.86667
# [419]	validation_0-aucpr:0.86533
# [420]	validation_0-aucpr:0.86530
# [421]	validation_0-aucpr:0.86546
# [422]	validation_0-aucpr:0.86540
# [423]	validation_0-aucpr:0.86540
# [424]	validation_0-aucpr:0.86475
# [425]	validation_0-aucpr:0.86477
# [426]	validation_0-aucpr:0.86464
# [427]	validation_0-aucpr:0.86475
# [428]	validation_0-aucpr:0.86487
# [429]	validation_0-aucpr:0.86556
# [430]	validation_0-aucpr:0.86554
# [431]	validation_0-aucpr:0.86491
# [432]	validation_0-aucpr:0.86491
# [433]	validation_0-aucpr:0.86594
# [434]	validation_0-aucpr:0.86569
# [435]	validation_0-aucpr:0.86503
# [436]	validation_0-aucpr:0.86582
# [437]	validation_0-aucpr:0.86591
# [438]	validation_0-aucpr:0.86675
# [439]	validation_0-aucpr:0.86680
# [440]	validation_0-aucpr:0.86645
# [441]	validation_0-aucpr:0.86586
# [442]	validation_0-aucpr:0.86587
# [443]	validation_0-aucpr:0.86583
# [444]	validation_0-aucpr:0.86597
# [445]	validation_0-aucpr:0.86563
# [446]	validation_0-aucpr:0.86516
# [447]	validation_0-aucpr:0.86588
# [448]	validation_0-aucpr:0.86526
# [449]	validation_0-aucpr:0.86531
# [450]	validation_0-aucpr:0.86525
# [451]	validation_0-aucpr:0.86588
# [452]	validation_0-aucpr:0.86568
# [453]	validation_0-aucpr:0.86586
# [454]	validation_0-aucpr:0.86581
# [455]	validation_0-aucpr:0.86557
# [456]	validation_0-aucpr:0.86584
# [457]	validation_0-aucpr:0.86596
# [458]	validation_0-aucpr:0.86705
# [459]	validation_0-aucpr:0.86583
# [460]	validation_0-aucpr:0.86551
# [461]	validation_0-aucpr:0.86544
# [462]	validation_0-aucpr:0.86549
# [463]	validation_0-aucpr:0.86560

# %%
# 6. Évaluation
print(classification_report(y_test, y_pred, digits=4))
print("F1-score:", f1_score(y_test, y_pred))

y_train_pred = best_model.predict(X_train)

# Évaluation sur train
print("\n=== Performance sur le train set ===")
print(classification_report(y_train, y_train_pred, digits=4))
print("F1-score (train) :", f1_score(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9997    0.9997    0.9997     15972
#            1     0.8214    0.8214    0.8214        28
#
#     accuracy                         0.9994     16000
#    macro avg     0.9106    0.9106    0.9106     16000
# weighted avg     0.9994    0.9994    0.9994     16000
#
# F1-score: 0.8214285714285714
#
# === Performance sur le train set ===
#               precision    recall  f1-score   support
#
#            0     1.0000    1.0000    1.0000     63936
#            1     0.9552    1.0000    0.9771        64
#
#     accuracy                         1.0000     64000
#    macro avg     0.9776    1.0000    0.9885     64000
# weighted avg     1.0000    1.0000    1.0000     64000
#
# F1-score (train) : 0.9770992366412213

# %%
# Proportion de la classe 1 dans le train
target_rate = (y_train == 1).mean()

# Probabilités sur test
y_test_proba = best_model.predict_proba(X_test)[:, 1]

# Seuil tel que top X% deviennent 1
threshold_quantile = np.quantile(y_test_proba, 1 - target_rate)
y_test_pred_forced_rate = (y_test_proba > threshold_quantile).astype(int)

print(f"Seuil forcé pour respecter {target_rate:.4%} : {threshold_quantile:.4f}")
print("F1-score :", f1_score(y_test, y_test_pred_forced_rate))
# Out:
# Seuil forcé pour respecter 0.1000% : 0.9997
# F1-score : 0.7272727272727273
